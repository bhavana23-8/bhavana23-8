# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavana23-8/bhavana23-8/blob/main/assingnment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path=('/content/Student_performance_data _.csv')
df=pd.read_csv(path)
df.mean(numeric_only=True)
# Out:
# StudentID            2196.500000
# Age                    16.468645
# Gender                  0.510870
# Ethnicity               0.877508
# ParentalEducation       1.746237
# StudyTimeWeekly         9.771992
# Absences               14.541388
# Tutoring                0.301421
# ParentalSupport         2.122074
# Extracurricular         0.383361
# Sports                  0.303512
# Music                   0.196906
# Volunteering            0.157191
# GPA                     1.906186
# GradeClass              2.983696
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#       StudentID   Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001  15.0     1.0        0.0                2.0         0.001057
# 1          1002   NaN     NaN        NaN                NaN         0.004859
# 2          1003   NaN     NaN        NaN                NaN         0.008031
# 3          1004   NaN     NaN        NaN                NaN         0.008206
# 4          1005   NaN     NaN        NaN                NaN         0.014337
# ...         ...   ...     ...        ...                ...              ...
# 2387       3388   NaN     NaN        NaN                NaN        19.939810
# 2388       3389   NaN     NaN        NaN                NaN        19.948459
# 2389       3390   NaN     NaN        NaN                NaN        19.968425
# 2390       3391   NaN     NaN        NaN                NaN        19.972346
# 2391       3392   NaN     NaN        NaN                NaN        19.978094
#
# ...

# %%
df.median(numeric_only=True)
# Out:
# StudentID            2196.500000
# Age                    16.000000
# Gender                  1.000000
# Ethnicity               0.000000
# ParentalEducation       2.000000
# StudyTimeWeekly         9.705363
# Absences               15.000000
# Tutoring                0.000000
# ParentalSupport         2.000000
# Extracurricular         0.000000
# Sports                  0.000000
# Music                   0.000000
# Volunteering            0.000000
# GPA                     1.893393
# GradeClass              4.000000
# dtype: float64

# %%
df.max() - df.min()
# Out:
# StudentID            2391.000000
# Age                     3.000000
# Gender                  1.000000
# Ethnicity               3.000000
# ParentalEducation       4.000000
# StudyTimeWeekly        19.977037
# Absences               29.000000
# Tutoring                1.000000
# ParentalSupport         4.000000
# Extracurricular         1.000000
# Sports                  1.000000
# Music                   1.000000
# Volunteering            1.000000
# GPA                     4.000000
# GradeClass              4.000000
# dtype: float64

# %%
df.var()
# Out:
# StudentID            477004.666667
# Age                       1.262923
# Gender                    0.249986
# Ethnicity                 1.057762
# ParentalEducation         1.000822
# StudyTimeWeekly          31.953857
# Absences                 71.697157
# Tutoring                  0.210655
# ParentalSupport           1.260709
# Extracurricular           0.236494
# Sports                    0.211481
# Music                     0.158200
# Volunteering              0.132537
# GPA                       0.837510
# GradeClass                1.522528
# dtype: float64

# %%
df.std()
# Out:
# StudentID            690.655244
# Age                    1.123798
# Gender                 0.499986
# Ethnicity              1.028476
# ParentalEducation      1.000411
# StudyTimeWeekly        5.652774
# Absences               8.467417
# Tutoring               0.458971
# ParentalSupport        1.122813
# Extracurricular        0.486307
# Sports                 0.459870
# Music                  0.397744
# Volunteering           0.364057
# GPA                    0.915156
# GradeClass             1.233908
# dtype: float64

# %%
df.cov(numeric_only=True)
# Out:
#                        StudentID        Age    Gender  Ethnicity  \
# StudentID          477004.666667 -32.796529 -5.050188  -9.227311
# Age                   -32.796529   1.262923  0.025226  -0.032910
# Gender                 -5.050188   0.025226  0.249986   0.008233
# Ethnicity              -9.227311  -0.032910  0.008233   1.057762
# ParentalEducation      -1.594103   0.028217  0.003387   0.034566
# StudyTimeWeekly       105.315683  -0.043198  0.032415   0.041763
# Absences               86.792346  -0.109534  0.090934  -0.223912
# Tutoring               -2.483271  -0.006229 -0.007251  -0.008232
# ParentalSupport         2.338770   0.041889  0.004528   0.024160
# Extracurricular        -1.212673  -0.013696 -0.001450  -0.004465
# Sports                 -6.575491  -0.023938 -0.002046  -0.002121
# Music                  -1.502091  -0.001561  0.001414  -0.005983
# Volunteering            2.014220   0.005349 -0.000036   0.005043
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                    StudentID       Age    Gender  Ethnicity  \
# StudentID           1.000000 -0.042255 -0.014625  -0.012990
# Age                -0.042255  1.000000  0.044895  -0.028473
# Gender             -0.014625  0.044895  1.000000   0.016010
# Ethnicity          -0.012990 -0.028473  0.016010   1.000000
# ParentalEducation  -0.002307  0.025099  0.006771   0.033595
# StudyTimeWeekly     0.026976 -0.006800  0.011469   0.007184
# Absences            0.014841 -0.011511  0.021479  -0.025712
# Tutoring           -0.007834 -0.012076 -0.031597  -0.017440
# ParentalSupport     0.003016  0.033197  0.008065   0.020922
# Extracurricular    -0.003611 -0.025061 -0.005964  -0.008927
# Sports             -0.020703 -0.046320 -0.008897  -0.004484
# Music              -0.005468 -0.003492  0.007109  -0.014627
# Volunteering        0.008011  0.013074 -0.000200   0.013468
# GPA                -0.002697  0.000275 -0.013360   0.027760
# GradeClass         -0.098500 -0.006250  0.022998  -0.023326
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('/content/Student_performance_data _.csv')

plt.figure(figsize=(16, 4))
plt.subplot(1, 4, 1)
plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('StudentID')
plt.title('Histogram ')

plt.subplot(1, 4, 2)
sns.boxplot(data=df, x='GradeClass', color='salmon')
plt.xlabel('Gradeclass')
plt.title('Box Plot')

plt.subplot(1, 4, 3)
sns.violinplot(data=df, x='Absences', color='orange')
plt.xlabel('Absences')
plt.title('Violin Plot ')

plt.subplot(1, 4, 4)
sns.displot(df['Extracurricular'], kde=True, color='purple')
plt.xlabel('Extracurricular')
plt.title('Distribution Plot ')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv('/content/Student_performance_data _.csv')

plt.figure(figsize=(16, 4))
plt.subplot(1, 4, 1)
plt.scatter(df['Age'], df['Sports'], color='green')
plt.xlabel('Age')
plt.ylabel('Sports')
plt.title('Scatter Plot')

plt.subplot(1, 4, 2)
sns.pairplot(df, vars=['ParentalSupport', 'StudyTimeWeekly', 'GPA'])

plt.subplot(1, 4, 3)
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap')

plt.subplot(1, 4, 4)
sns.jointplot(x='ParentalSupport', y='Age', data=df, kind='hex', color='purple')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-ec4e372d73dc>:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, 3)

# %%
import pandas as pd
import scipy.stats as stats
df=pd.read_csv('/content/Student_performance_data _.csv')
Music_df=df['Music'].values
t_stat, p_val=stats.ttest_1samp(Music_df, popmean=0)
print(f"One-sample t-test: t_stat={t_stat}, p_val={p_val}")
# Out:
# One-sample t-test: t_stat=24.212328591117974, p_val=5.160805907563638e-116

# %%
import pandas as pd
from scipy.stats import chi2_contingency
df=pd.read_csv('/content/Student_performance_data _.csv')
contingency_table=pd.crosstab(df['GradeClass'],df['Extracurricular'])
chi2, p, dof, ex = chi2_contingency(contingency_table)
print(f"Chi-Square Test of Independent: chi2={chi2}, p={p}, dog={dof}, expected={ex}")
# Out:
# Chi-Square Test of Independent: chi2=14.217072478079004, p=0.006633525439525457, dog=4, expected=[[ 65.98035117  41.01964883]
#  [165.87583612 103.12416388]
#  [241.10576923 149.89423077]
#  [255.28846154 158.71153846]
#  [746.74958194 464.25041806]]

# %%
import numpy as np
from scipy import stats
df = pd.read_csv('//content/Student_performance_data _.csv')
groups = df.groupby('Sports')['GradeClass'].apply(list)
f_value, p_value=stats.f_oneway(*groups)
print(f"F-value: {f_value}")
print(f"P-value: {p_value}")
# Out:
# F-value: 1.699187224177797
# P-value: 0.19251985407479533

# %%
import numpy as np
from scipy.stats import kruskal
data=pd.read_csv('/content/Student_performance_data _.csv')

h_stat, p_val = kruskal('Sports', 'Music', 'GPA')
print(f"Kruskal-Wallis Test: H_stat={h_stat}, p_val={p_val}")
# Out:
# Kruskal-Wallis Test: H_stat=2.0, p_val=0.36787944117144245

# %%
import pandas as pd

# %%
path=('/content/data.csv')
df=pd.read_csv(path)
df.mean(numeric_only=True)
# Out:
# footfall       306.381356
# tempMode         3.727754
# AQ               4.325212
# USS              2.939619
# CS               5.394068
# VOC              2.842161
# RP              47.043432
# IP               4.565678
# Temperature     16.331568
# fail             0.416314
# dtype: float64

# %%
df. mode(numeric_only=True)
# Out:
#    footfall  tempMode  AQ  USS  CS  VOC  RP  IP  Temperature  fail
# 0         0         7   4    2   6    0  35   3           21     0

# %%
df.median (numeric_only=True)
# Out:
# footfall       22.0
# tempMode        3.0
# AQ              4.0
# USS             3.0
# CS              6.0
# VOC             2.0
# RP             44.0
# IP              4.0
# Temperature    17.0
# fail            0.0
# dtype: float64

# %%
df.max() -df. min()
# Out:
# footfall       7300
# tempMode          7
# AQ                6
# USS               6
# CS                6
# VOC               6
# RP               72
# IP                6
# Temperature      23
# fail              1
# dtype: int64

# %%
df.var()
# Out:
# footfall       1.172037e+06
# tempMode       7.167585e+00
# AQ             2.069099e+00
# USS            1.914696e+00
# CS             1.611248e+00
# VOC            5.168061e+00
# RP             2.697192e+02
# IP             2.557718e+00
# Temperature    3.569801e+01
# fail           2.432543e-01
# dtype: float64

# %%
df.std()
# Out:
# footfall       1082.606745
# tempMode          2.677235
# AQ                1.438436
# USS               1.383725
# CS                1.269349
# VOC               2.273337
# RP               16.423130
# IP                1.599287
# Temperature       5.974781
# fail              0.493208
# dtype: float64

# %%
df.cov()
# Out:
#                  footfall   tempMode          AQ        USS         CS  \
# footfall     1.172037e+06  59.292692 -102.493188  29.140761  35.232381
# tempMode     5.929269e+01   7.167585   -0.041803   0.007934  -0.047428
# AQ          -1.024932e+02  -0.041803    2.069099  -0.312262  -0.164347
# USS          2.914076e+01   0.007934   -0.312262   1.914696  -0.619871
# CS           3.523238e+01  -0.047428   -0.164347  -0.619871   1.611248
# VOC         -2.204933e+02  -0.318732    2.022754  -1.256624   0.138617
# RP          -7.773262e+02  17.973661    2.236125  -0.739686  -0.562202
# IP          -6.699517e+00  -0.248803   -0.243545  -0.456794   0.377060
# Temperature -1.164882e+02  -1.000835    0.295025  -1.861188   1.091895
# fail        -3.901365e+01  -0.019096    0.413777  -0.318420   0.011804
#
#                     VOC          RP        IP  Temperature       fail
# footfall    -220.493296 -777.326231 -6.699517  -116.488191 -39.013651
# ...

# %%
df.corr()
# Out:
#              footfall  tempMode        AQ       USS        CS       VOC  \
# footfall     1.000000  0.020457 -0.065816  0.019453  0.025638 -0.089590
# tempMode     0.020457  1.000000 -0.010855  0.002142 -0.013956 -0.052369
# AQ          -0.065816 -0.010855  1.000000 -0.156884 -0.090010  0.618570
# USS          0.019453  0.002142 -0.156884  1.000000 -0.352915 -0.399477
# CS           0.025638 -0.013956 -0.090010 -0.352915  1.000000  0.048037
# VOC         -0.089590 -0.052369  0.618570 -0.399477  0.048037  1.000000
# RP          -0.043720  0.408784  0.094656 -0.032549 -0.026968  0.008023
# IP          -0.003869 -0.058109 -0.105868 -0.206416  0.185739  0.103628
# Temperature -0.018009 -0.062568  0.034328 -0.225122  0.143972  0.208956
# fail        -0.073066 -0.014462  0.583238 -0.466574  0.018855  0.797329
#
#                    RP        IP  Temperature      fail
# footfall    -0.043720 -0.003869    -0.018009 -0.073066
# tempMode     0.408784 -0.058109    -0.062568 -0.014462
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df = pd.read_csv('/content/data.csv')

plt.figure(figsize=(16, 4))
plt.subplot(1, 4, 1)
plt.hist(df['AQ'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('AQ')
plt.ylabel('tempMode')
plt.title('Histogram ')

plt.subplot(1, 4, 2)
sns.boxplot(data=df, x='CS', color='salmon')
plt.xlabel('CS')
plt.title('Box Plot')

plt.subplot(1, 4, 3)
sns.violinplot(data=df, x='USS', color='orange')
plt.xlabel('USS')
plt.title('Violin Plot ')

plt.subplot(1, 4, 4)
sns.displot(df['VOC'], kde=True, color='purple')
plt.xlabel('VOC')
plt.title('Distribution Plot ')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv('/content/data.csv')

plt.figure(figsize=(16, 4))
plt.subplot(1, 4, 1)
plt.scatter(df['AQ'], df['USS'], color='green')
plt.xlabel('AQ')
plt.ylabel('USS')
plt.title('Scatter Plot')

plt.subplot(1, 4, 2)
sns.pairplot(df, vars=['VOC', 'RP', 'IP'])

plt.subplot(1, 4, 3)
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap')

plt.subplot(1, 4, 4)
sns.jointplot(x='RP', y='Temperature', data=df, kind='hex', color='purple')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-63-c725cd8a3383>:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 4, 3)

# %%
import pandas as pd
import scipy.stats as stats
df=pd.read_csv('/content/data.csv')
RP_df=df['RP'].values
t_stat, p_val=stats.ttest_1samp(RP_df, popmean=0)
print(f"One-sample t-test: t_stat={t_stat}, p_val={p_val}")
# Out:
# One-sample t-test: t_stat=88.00939865785676, p_val=0.0

# %%
import pandas as pd
from scipy.stats import chi2_contingency
df=pd.read_csv('/content/data.csv')
contingency_table=pd.crosstab(df['Temperature'],df['USS'])
chi2, p, dof, ex = chi2_contingency(contingency_table)
print(f"Chi-Square Test of Independent: chi2={chi2}, p={p}, dog={dof}, expected={ex}")
# Out:
# Chi-Square Test of Independent: chi2=219.87304202169008, p=1.153660451699829e-05, dog=138, expected=[[ 2.19385593  6.38029661  4.75        3.22033898  1.34851695  0.72457627
#    0.38241525]
#  [ 1.38559322  4.02966102  3.          2.03389831  0.85169492  0.45762712
#    0.24152542]
#  [ 1.96292373  5.70868644  4.25        2.88135593  1.2065678   0.64830508
#    0.34216102]
#  [ 2.19385593  6.38029661  4.75        3.22033898  1.34851695  0.72457627
#    0.38241525]
#  [ 2.07838983  6.04449153  4.5         3.05084746  1.27754237  0.68644068
#    0.36228814]
#  [ 1.50105932  4.3654661   3.25        2.20338983  0.92266949  0.49576271
#    0.26165254]
#  [ 1.27012712  3.69385593  2.75        1.86440678  0.78072034  0.41949153
#    0.22139831]
#  [ 1.96292373  5.70868644  4.25        2.88135593  1.2065678   0.64830508
#    0.34216102]
#  [ 1.15466102  3.35805085  2.5         1.69491525  0.70974576  0.38135593
#    0.20127119]
# ...

# %%
import numpy as np
from scipy import stats
df = pd.read_csv('/content/data.csv')
groups = df.groupby('CS')['IP'].apply(list)
f_value, p_value=stats.f_oneway(*groups)
print(f"F-value: {f_value}")
print(f"P-value: {p_value}")
# Out:
# F-value: 13.76493466702094
# P-value: 4.941327681942351e-15

# %%
import numpy as np
from scipy.stats import kruskal
data=pd.read_csv('/content/data.csv')

h_stat, p_val = kruskal('tempMode', 'VOC', 'CS')
print(f"Kruskal-Wallis Test: H_stat={h_stat}, p_val={p_val}")
# Out:
# Kruskal-Wallis Test: H_stat=2.0, p_val=0.36787944117144245

# %%
import pandas as pd
from scipy.stats import norm
df=pd.read_csv("/content/Student_performance_data _.csv")
mean_Sports=df["Sports"].mean()
std_Sports=df["Sports"].std()
value=1
z_score=(value-mean_Sports)/std_Sports
probability=1-norm.cdf(z_score)
print(f"probability Sports greater than ${value}:{probability:.2%}")
# Out:
# probability Sports greater than $1:6.49%

# %%
import pandas as pd
from scipy.stats import norm
df=pd.read_csv("/content/data.csv")
mean_AQ=df["AQ"].mean()
std_AQ=df["AQ"].std()
value=1
z_score=(value-mean_AQ)/std_AQ
probability=1-norm.cdf(z_score)
print(f"probability AQ greater than ${value}:{probability:.2%}")
# Out:
# probability AQ greater than $1:98.96%

# %%
import pandas as pd
df=pd.read_csv('/content/Student_performance_data _.csv')
print(df.columns)
total_count=df['Age'].sum()
df["probablity"]=df["Age"]/total_count
print(df)
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/data.csv')
print(df.columns)
total_count=df['USS'].sum()
df["probablity"]=df["USS"]/total_count
print(df)
# Out:
# Index(['footfall', 'tempMode', 'AQ', 'USS', 'CS', 'VOC', 'RP', 'IP',
#        'Temperature', 'fail'],
#       dtype='object')
#      footfall  tempMode  AQ  USS  CS  VOC  RP  IP  Temperature  fail  \
# 0           0         7   7    1   6    6  36   3            1     1
# 1         190         1   3    3   5    1  20   4            1     0
# 2          31         7   2    2   6    1  24   6            1     0
# 3          83         4   3    4   5    1  28   6            1     0
# 4         640         7   5    6   4    0  68   6            1     0
# ..        ...       ...  ..  ...  ..  ...  ..  ..          ...   ...
# 939         0         7   7    1   6    4  73   6           24     1
# 940         0         7   5    2   6    6  50   6           24     1
# 941         0         3   6    2   7    5  43   6           24     1
# 942         0         6   6    2   5    6  46   7           24     1
# 943        18         7   4    2   6    3  61   7           24     1
#
# ...
